# %%
import pandas as pd
import sklearn 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex_binary'] = np.where(df['Sex'] == "female", 1, 0)
df.drop(columns='Sex', inplace=True)

# %%
# set Embarked_ternary to 1 for C, 2 for Q, 3 for S
df['Embarked_ternary'] = np.where(df["Embarked"] == "C", 1, 
         (np.where(df["Embarked"] == "Q", 2, 3)))

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# 5                                     Moran, Mr. James   NaN      0      0
# 6                              McCarthy, Mr. Timothy J  54.0      0      0
# 7                       Palsson, Master. Gosta Leonard   2.0      3      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      0      2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0      1      0
# 10                     Sandstrom, Miss. Marguerite Rut   4.0      1      1
# 11                            Bonnell, Miss. Elizabeth  58.0      0      0
# 12                      Saundercock, Mr. William Henry  20.0      0      0
# 13                         Andersson, Mr. Anders Johan  39.0      1      5
# 14                Vestrom, Miss. Hulda Amanda Adolfina  14.0      0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   55.0      0      0
# 16                                Rice, Master. Eugene   2.0      4      1
# 17                        Williams, Mr. Charles Eugene   NaN      0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0      1      0
# 19                             Masselmani, Mrs. Fatima   NaN      0      0
# 20                                Fynney, Mr. Joseph J  35.0      0      0
# 21                               Beesley, Mr. Lawrence  34.0      0      0
# 22                         McGowan, Miss. Anna "Annie"  15.0      0      0
# 23                        Sloper, Mr. William Thompson  28.0      0      0
# 24                       Palsson, Miss. Torborg Danira   8.0      3      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0      1      5
# 26                             Emir, Mr. Farred Chehab   NaN      0      0
# 27                      Fortune, Mr. Charles Alexander  19.0      3      2
# 28                       O'Dwyer, Miss. Ellen "Nellie"   NaN      0      0
# 29                                 Todoroff, Mr. Lalio   NaN      0      0
# ..                                                 ...   ...    ...    ...
# 861                        Giles, Mr. Frederick Edward  21.0      1      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0      0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"   NaN      8      2
# 864                             Gill, Mr. John William  24.0      0      0
# 865                           Bystrom, Mrs. (Karolina)  42.0      0      0
# 866                       Duran y More, Miss. Asuncion  27.0      1      0
# 867               Roebling, Mr. Washington Augustus II  31.0      0      0
# 868                        van Melkebeke, Mr. Philemon   NaN      0      0
# 869                    Johnson, Master. Harold Theodor   4.0      1      1
# 870                                  Balkic, Mr. Cerin  26.0      0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1      1
# 872                           Carlsson, Mr. Frans Olof  33.0      0      0
# 873                        Vander Cruyssen, Mr. Victor  47.0      0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0      1      0
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0      0      0
# 876                      Gustafsson, Mr. Alfred Ossian  20.0      0      0
# 877                               Petroff, Mr. Nedelio  19.0      0      0
# 878                                 Laleff, Mr. Kristo   NaN      0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0      1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0      0      1
# 881                                 Markun, Mr. Johann  33.0      0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0      0      0
# 883                      Banfield, Mr. Frederick James  28.0      0      0
# 884                             Sutehall, Mr. Henry Jr  25.0      0      0
# 885               Rice, Mrs. William (Margaret Norton)  39.0      0      5
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                       Graham, Miss. Margaret Edith  19.0      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN      1      2
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket      Fare        Cabin Embarked  Sex_binary  \
# 0           A/5 21171    7.2500          NaN        S           0
# 1            PC 17599   71.2833          C85        C           1
# 2    STON/O2. 3101282    7.9250          NaN        S           1
# 3              113803   53.1000         C123        S           1
# 4              373450    8.0500          NaN        S           0
# 5              330877    8.4583          NaN        Q           0
# 6               17463   51.8625          E46        S           0
# 7              349909   21.0750          NaN        S           0
# 8              347742   11.1333          NaN        S           1
# 9              237736   30.0708          NaN        C           1
# 10            PP 9549   16.7000           G6        S           1
# 11             113783   26.5500         C103        S           1
# 12          A/5. 2151    8.0500          NaN        S           0
# 13             347082   31.2750          NaN        S           0
# 14             350406    7.8542          NaN        S           1
# 15             248706   16.0000          NaN        S           1
# 16             382652   29.1250          NaN        Q           0
# 17             244373   13.0000          NaN        S           0
# 18             345763   18.0000          NaN        S           1
# 19               2649    7.2250          NaN        C           1
# 20             239865   26.0000          NaN        S           0
# 21             248698   13.0000          D56        S           0
# 22             330923    8.0292          NaN        Q           1
# 23             113788   35.5000           A6        S           0
# 24             349909   21.0750          NaN        S           1
# 25             347077   31.3875          NaN        S           1
# 26               2631    7.2250          NaN        C           0
# 27              19950  263.0000  C23 C25 C27        S           0
# 28             330959    7.8792          NaN        Q           1
# 29             349216    7.8958          NaN        S           0
# ..                ...       ...          ...      ...         ...
# 861             28134   11.5000          NaN        S           0
# 862             17466   25.9292          D17        S           1
# 863          CA. 2343   69.5500          NaN        S           1
# 864            233866   13.0000          NaN        S           0
# 865            236852   13.0000          NaN        S           1
# 866     SC/PARIS 2149   13.8583          NaN        C           1
# 867          PC 17590   50.4958          A24        S           0
# 868            345777    9.5000          NaN        S           0
# 869            347742   11.1333          NaN        S           0
# 870            349248    7.8958          NaN        S           0
# 871             11751   52.5542          D35        S           1
# 872               695    5.0000  B51 B53 B55        S           0
# 873            345765    9.0000          NaN        S           0
# 874         P/PP 3381   24.0000          NaN        C           1
# 875              2667    7.2250          NaN        C           1
# 876              7534    9.8458          NaN        S           0
# 877            349212    7.8958          NaN        S           0
# 878            349217    7.8958          NaN        S           0
# 879             11767   83.1583          C50        C           1
# 880            230433   26.0000          NaN        S           1
# 881            349257    7.8958          NaN        S           0
# 882              7552   10.5167          NaN        S           1
# 883  C.A./SOTON 34068   10.5000          NaN        S           0
# 884   SOTON/OQ 392076    7.0500          NaN        S           0
# 885            382652   29.1250          NaN        Q           1
# 886            211536   13.0000          NaN        S           0
# 887            112053   30.0000          B42        S           1
# 888        W./C. 6607   23.4500          NaN        S           1
# 889            111369   30.0000         C148        C           0
# 890            370376    7.7500          NaN        Q           0
#
#      Embarked_ternary
# 0                   3
# 1                   1
# 2                   3
# 3                   3
# 4                   3
# 5                   2
# 6                   3
# 7                   3
# 8                   3
# 9                   1
# 10                  3
# 11                  3
# 12                  3
# 13                  3
# 14                  3
# 15                  3
# 16                  2
# 17                  3
# 18                  3
# 19                  1
# 20                  3
# 21                  3
# 22                  2
# 23                  3
# 24                  3
# 25                  3
# 26                  1
# 27                  3
# 28                  2
# 29                  3
# ..                ...
# 861                 3
# 862                 3
# 863                 3
# 864                 3
# 865                 3
# 866                 1
# 867                 3
# 868                 3
# 869                 3
# 870                 3
# 871                 3
# 872                 3
# 873                 3
# 874                 1
# 875                 1
# 876                 3
# 877                 3
# 878                 3
# 879                 1
# 880                 3
# 881                 3
# 882                 3
# 883                 3
# 884                 3
# 885                 2
# 886                 3
# 887                 3
# 888                 3
# 889                 1
# 890                 2
#
# [891 rows x 13 columns]

# %%
count_nan = len(df['Cabin']) - df['Cabin'].count()

# %%
count_nan
# Out:
# 687

# %% [markdown]
# OK, so most of the Cabin values are NaN, so we can probably drop this column.

# %%
df.drop(columns='Cabin', inplace=True)

# %% [markdown]
# Not sure about name column, might be useful data in len(name)?

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# 22             330923    8.0292        Q           1                 2
# 23             113788   35.5000        S           0                 3
# 24             349909   21.0750        S           1                 3
# 25             347077   31.3875        S           1                 3
# 26               2631    7.2250        C           0                 1
# 27              19950  263.0000        S           0                 3
# 28             330959    7.8792        Q           1                 2
# 29             349216    7.8958        S           0                 3
# ..                ...       ...      ...         ...               ...
# 861             28134   11.5000        S           0                 3
# 862             17466   25.9292        S           1                 3
# 863          CA. 2343   69.5500        S           1                 3
# 864            233866   13.0000        S           0                 3
# 865            236852   13.0000        S           1                 3
# 866     SC/PARIS 2149   13.8583        C           1                 1
# 867          PC 17590   50.4958        S           0                 3
# 868            345777    9.5000        S           0                 3
# 869            347742   11.1333        S           0                 3
# 870            349248    7.8958        S           0                 3
# 871             11751   52.5542        S           1                 3
# 872               695    5.0000        S           0                 3
# 873            345765    9.0000        S           0                 3
# 874         P/PP 3381   24.0000        C           1                 1
# 875              2667    7.2250        C           1                 1
# 876              7534    9.8458        S           0                 3
# 877            349212    7.8958        S           0                 3
# 878            349217    7.8958        S           0                 3
# 879             11767   83.1583        C           1                 1
# 880            230433   26.0000        S           1                 3
# 881            349257    7.8958        S           0                 3
# 882              7552   10.5167        S           1                 3
# 883  C.A./SOTON 34068   10.5000        S           0                 3
# 884   SOTON/OQ 392076    7.0500        S           0                 3
# 885            382652   29.1250        Q           1                 2
# 886            211536   13.0000        S           0                 3
# 887            112053   30.0000        S           1                 3
# 888        W./C. 6607   23.4500        S           1                 3
# 889            111369   30.0000        C           0                 1
# 890            370376    7.7500        Q           0                 2
#
# [891 rows x 12 columns]

# %%
# Slightly more likely to survive if younger
df.groupby(['Survived']).Age.mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
df.groupby(['Survived']).Fare.mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
# who embarked at Cherbourg?
print("number embarked at Cherbourg", len(df.loc[df['Embarked_ternary'] == 1]))

print("average survival status", df.loc[df['Embarked_ternary'] == 1].Survived.mean())
# Out:
# number embarked at Cherbourg 168
# average survival status 0.5535714285714286

# %%
# who embarked at Queenstown?

print("number embarked at Queenstown", len(df.loc[df['Embarked_ternary'] == 2]))

print("average survival status", df.loc[df['Embarked_ternary'] == 2].Survived.mean())
# Out:
# number embarked at Queenstown 77
# average survival status 0.38961038961038963

# %%
# who embarked at Southampton?
print("number embarked at Southampton", len(df.loc[df['Embarked_ternary'] == 3]))

print("average survival status", df.loc[df['Embarked_ternary'] == 3].Survived.mean())
# Out:
# number embarked at Southampton 646
# average survival status 0.33900928792569657

# %% [markdown]
# OK, so there is some evidence that embarking at Cherbourg is correlated with survival. So let's turn embarkation_ternary into a binary condition: emarbarked_at_cherbourg

# %%
df['Embarked_at_cherbourg'] = np.where(df['Embarked_ternary'] == 1, 1, 0)

# %%
df.dtypes
# Out:
# PassengerId                int64
# Survived                   int64
# Pclass                     int64
# Name                      object
# Age                      float64
# SibSp                      int64
# Parch                      int64
# Ticket                    object
# Fare                     float64
# Embarked                  object
# Sex_binary                 int64
# Embarked_ternary           int64
# Embarked_at_cherbourg      int64
# dtype: object

# %%
df.drop(columns="Embarked_ternary", inplace=True)

# %%
# how do the name lengths vary? And are they correlated with survival?

names_lens = [(name[1], len(name[1])) for name in df["Name"].iteritems()]
name_lens = [name_len[1] for name_len in names_lens]
plt.hist(name_lens)
plt.show()

# %%
# add an int value for name length
df['Name_len'] = [len(name[1]) for name in df["Name"].iteritems()]

# %%
df.corr()
# Out:
#                        PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId               1.000000 -0.005007 -0.035144  0.036847 -0.057527
# Survived                 -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass                   -0.035144 -0.338481  1.000000 -0.369226  0.083081
# Age                       0.036847 -0.077221 -0.369226  1.000000 -0.308247
# SibSp                    -0.057527 -0.035322  0.083081 -0.308247  1.000000
# Parch                    -0.001652  0.081629  0.018443 -0.189119  0.414838
# Fare                      0.012658  0.257307 -0.549500  0.096067  0.159651
# Sex_binary               -0.042939  0.543351 -0.131900 -0.093254  0.114631
# Embarked_at_cherbourg    -0.001205  0.168240 -0.243292  0.036261 -0.059528
# Name_len                 -0.012986  0.332350 -0.220001  0.034612  0.165019
#
#                           Parch      Fare  Sex_binary  Embarked_at_cherbourg  \
# PassengerId           -0.001652  0.012658   -0.042939              -0.001205
# Survived               0.081629  0.257307    0.543351               0.168240
# Pclass                 0.018443 -0.549500   -0.131900              -0.243292
# Age                   -0.189119  0.096067   -0.093254               0.036261
# SibSp                  0.414838  0.159651    0.114631              -0.059528
# Parch                  1.000000  0.216225    0.245489              -0.011069
# Fare                   0.216225  1.000000    0.182333               0.269335
# Sex_binary             0.245489  0.182333    1.000000               0.082853
# Embarked_at_cherbourg -0.011069  0.269335    0.082853               1.000000
# Name_len               0.252282  0.155832    0.448759               0.027481
#
#                        Name_len
# PassengerId           -0.012986
# Survived               0.332350
# Pclass                -0.220001
# Age                    0.034612
# SibSp                  0.165019
# Parch                  0.252282
# Fare                   0.155832
# Sex_binary             0.448759
# Embarked_at_cherbourg  0.027481
# Name_len               1.000000

# %%
# woah, having a long name is almost as highly correlated with survival as passanger class!

# %%
# todo: engineer ticket class
# for now, we'll just drop it

df.drop(columns=['PassengerId', 'Embarked', 'Name', 'Ticket'], inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_binary  \
# 0         0       3  22.0      1      0   7.2500           0
# 1         1       1  38.0      1      0  71.2833           1
# 2         1       3  26.0      0      0   7.9250           1
# 3         1       1  35.0      1      0  53.1000           1
# 4         0       3  35.0      0      0   8.0500           0
#
#    Embarked_at_cherbourg  Name_len
# 0                      0        23
# 1                      1        51
# 2                      0        22
# 3                      0        44
# 4                      0        24

# %%
df.dtypes
# Out:
# Survived                   int64
# Pclass                     int64
# Age                      float64
# SibSp                      int64
# Parch                      int64
# Fare                     float64
# Sex_binary                 int64
# Embarked_at_cherbourg      int64
# Name_len                   int64
# dtype: object

# %%
df.isnull().any()
# Out:
# Survived                 False
# Pclass                   False
# Age                       True
# SibSp                    False
# Parch                    False
# Fare                     False
# Sex_binary               False
# Embarked_at_cherbourg    False
# Name_len                 False
# dtype: bool

# %% [markdown]
# We have some null ages. Let's see how many.

# %%
len(df.loc[df.Age.isnull()])
# Out:
#      Embarked_at_cherbourg  Name_len
# 0                        0        23
# 1                        1        51
# 2                        0        22
# 3                        0        44
# 4                        0        24
# 5                        0        16
# 6                        0        23
# 7                        0        30
# 8                        0        49
# 9                        1        35
# 10                       0        31
# 11                       0        24
# 12                       0        30
# 13                       0        27
# 14                       0        36
# 15                       0        32
# 16                       0        20
# 17                       0        28
# 18                       0        55
# 19                       1        23
# 20                       0        20
# 21                       0        21
# 22                       0        27
# 23                       0        28
# 24                       0        29
# 25                       0        57
# 26                       1        23
# 27                       0        30
# 28                       0        29
# 29                       0        19
# ..                     ...       ...
# 861                      0        27
# 862                      0        51
# 863                      0        33
# 864                      0        22
# 865                      0        24
# 866                      1        28
# 867                      0        36
# 868                      0        27
# 869                      0        31
# 870                      0        17
# 871                      0        48
# 872                      0        24
# 873                      0        27
# 874                      1        37
# 875                      1        32
# 876                      0        29
# 877                      0        20
# 878                      0        18
# 879                      1        45
# 880                      0        44
# 881                      0        18
# 882                      0        28
# 883                      0        29
# 884                      0        22
# 885                      0        36
# 886                      0        21
# 887                      0        28
# 888                      0        40
# 889                      1        21
# 890                      0        19
#
# [891 rows x 9 columns]

# %%
(train_passengers, train_labels) = (df.drop('Survived', axis=1), df['Survived'])

# %%
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch      Fare  Sex_binary  \
# 0           0       3  22.000000      1      0    7.2500           0
# 1           1       1  38.000000      1      0   71.2833           1
# 2           1       3  26.000000      0      0    7.9250           1
# 3           1       1  35.000000      1      0   53.1000           1
# 4           0       3  35.000000      0      0    8.0500           0
# 5           0       3  29.699118      0      0    8.4583           0
# 6           0       1  54.000000      0      0   51.8625           0
# 7           0       3   2.000000      3      1   21.0750           0
# 8           1       3  27.000000      0      2   11.1333           1
# 9           1       2  14.000000      1      0   30.0708           1
# 10          1       3   4.000000      1      1   16.7000           1
# 11          1       1  58.000000      0      0   26.5500           1
# 12          0       3  20.000000      0      0    8.0500           0
# 13          0       3  39.000000      1      5   31.2750           0
# 14          0       3  14.000000      0      0    7.8542           1
# 15          1       2  55.000000      0      0   16.0000           1
# 16          0       3   2.000000      4      1   29.1250           0
# 17          1       2  29.699118      0      0   13.0000           0
# 18          0       3  31.000000      1      0   18.0000           1
# 19          1       3  29.699118      0      0    7.2250           1
# 20          0       2  35.000000      0      0   26.0000           0
# 21          1       2  34.000000      0      0   13.0000           0
# 22          1       3  15.000000      0      0    8.0292           1
# 23          1       1  28.000000      0      0   35.5000           0
# 24          0       3   8.000000      3      1   21.0750           1
# 25          1       3  38.000000      1      5   31.3875           1
# 26          0       3  29.699118      0      0    7.2250           0
# 27          0       1  19.000000      3      2  263.0000           0
# 28          1       3  29.699118      0      0    7.8792           1
# 29          0       3  29.699118      0      0    7.8958           0
# ..        ...     ...        ...    ...    ...       ...         ...
# 861         0       2  21.000000      1      0   11.5000           0
# 862         1       1  48.000000      0      0   25.9292           1
# 863         0       3  29.699118      8      2   69.5500           1
# 864         0       2  24.000000      0      0   13.0000           0
# 865         1       2  42.000000      0      0   13.0000           1
# 866         1       2  27.000000      1      0   13.8583           1
# 867         0       1  31.000000      0      0   50.4958           0
# 868         0       3  29.699118      0      0    9.5000           0
# 869         1       3   4.000000      1      1   11.1333           0
# 870         0       3  26.000000      0      0    7.8958           0
# 871         1       1  47.000000      1      1   52.5542           1
# 872         0       1  33.000000      0      0    5.0000           0
# 873         0       3  47.000000      0      0    9.0000           0
# 874         1       2  28.000000      1      0   24.0000           1
# 875         1       3  15.000000      0      0    7.2250           1
# 876         0       3  20.000000      0      0    9.8458           0
# 877         0       3  19.000000      0      0    7.8958           0
# 878         0       3  29.699118      0      0    7.8958           0
# 879         1       1  56.000000      0      1   83.1583           1
# 880         1       2  25.000000      0      1   26.0000           1
# 881         0       3  33.000000      0      0    7.8958           0
# 882         0       3  22.000000      0      0   10.5167           1
# 883         0       2  28.000000      0      0   10.5000           0
# 884         0       3  25.000000      0      0    7.0500           0
# 885         0       3  39.000000      0      5   29.1250           1
# 886         0       2  27.000000      0      0   13.0000           0
# 887         1       1  19.000000      0      0   30.0000           1
# 888         0       3  29.699118      1      2   23.4500           1
# 889         1       1  26.000000      0      0   30.0000           0
# 890         0       3  32.000000      0      0    7.7500           0
#
#      Embarked_at_cherbourg  Name_len
# 0                        0        23
# 1                        1        51
# 2                        0        22
# 3                        0        44
# 4                        0        24
# 5                        0        16
# 6                        0        23
# 7                        0        30
# 8                        0        49
# 9                        1        35
# 10                       0        31
# 11                       0        24
# 12                       0        30
# 13                       0        27
# 14                       0        36
# 15                       0        32
# 16                       0        20
# 17                       0        28
# 18                       0        55
# 19                       1        23
# 20                       0        20
# 21                       0        21
# 22                       0        27
# 23                       0        28
# 24                       0        29
# 25                       0        57
# 26                       1        23
# 27                       0        30
# 28                       0        29
# 29                       0        19
# ..                     ...       ...
# 861                      0        27
# 862                      0        51
# 863                      0        33
# 864                      0        22
# 865                      0        24
# 866                      1        28
# 867                      0        36
# 868                      0        27
# 869                      0        31
# 870                      0        17
# 871                      0        48
# 872                      0        24
# 873                      0        27
# 874                      1        37
# 875                      1        32
# 876                      0        29
# 877                      0        20
# 878                      0        18
# 879                      1        45
# 880                      0        44
# 881                      0        18
# 882                      0        28
# 883                      0        29
# 884                      0        22
# 885                      0        36
# 886                      0        21
# 887                      0        28
# 888                      0        40
# 889                      1        21
# 890                      0        19
#
# [891 rows x 9 columns]

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(train_passengers)
scaler.transform(train_passengers, copy=False)
# Out:
# array([[ 0.82737724, -0.5924806 ,  0.43279337, ..., -0.73769513,
#         -0.48204268, -0.42745127],
#        [-1.56610693,  0.63878901,  0.43279337, ...,  1.35557354,
#          2.0745051 ,  2.59096206],
#        [ 0.82737724, -0.2846632 , -0.4745452 , ...,  1.35557354,
#         -0.48204268, -0.53525175],
#        ...,
#        [ 0.82737724,  0.        ,  0.43279337, ...,  1.35557354,
#         -0.48204268,  1.40515682],
#        [-1.56610693, -0.2846632 , -0.4745452 , ..., -0.73769513,
#          2.0745051 , -0.64305222],
#        [ 0.82737724,  0.17706291, -0.4745452 , ..., -0.73769513,
#         -0.48204268, -0.85865317]])

# %%
# urgh, standardscaler returns a numpy array, not df

# scaler.transform(train_passengers, copy=False) let's try something else

# %%
    # train_passengers is df
train_passengers[train_passengers.columns] = scaler.fit_transform(train_passengers[train_passengers.columns])

# %%
# make a function with preceding data-wrangling steps, so that we can perform the same operations on the test set
def wrangle(df):
    """
    takes a df with same format as training set.
    returns df in same format as modified training set
    """
    df['Sex_binary'] = np.where(df['Sex'] == "female", 1, 0)
    df.drop(columns='Sex', inplace=True)
    df['Embarked_ternary'] = np.where(df["Embarked"] == "C", 1, 
         (np.where(df["Embarked"] == "Q", 2, 3)))
    df.drop(columns='Cabin', inplace=True)
    df['Embarked_at_cherbourg'] = np.where(df['Embarked_ternary'] == 1, 1, 0)
    df.drop(columns="Embarked_ternary", inplace=True)
    names_lens = [(name[1], len(name[1])) for name in df["Name"].iteritems()]
    name_lens = [name_len[1] for name_len in names_lens]
    df['Name_len'] = [len(name[1]) for name in df["Name"].iteritems()]    
    df.drop(columns=['PassengerId', 'Embarked', 'Name', 'Ticket'], inplace=True)
    
    # naively fill in nulls for now
    df.fillna(df.mean(), inplace=True)
    return df

# %%
# load and transform test data
df_test = pd.read_csv("test.csv")
df_test = wrangle(df_test)

# %%
import keras
from keras import models 
from keras import layers
from keras import regularizers
# Out:
# /Users/kate/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
test_passengers = df_test

# %%
test_passengers[test_passengers.columns] = scaler.fit_transform(test_passengers[test_passengers.columns])

# %%
train_passengers.shape
# Out:
# (891, 8)

# %%
network = models.Sequential()
network.add(layers.Dense(714, activation='relu', input_shape=(8,))) # experiment with different activation functions

keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones', moving_mean_initializer='zeros', moving_variance_initializer='ones', beta_regularizer=None, gamma_regularizer=None, beta_constraint=None, gamma_constraint=None)
network.add(layers.Dense(714, activation='relu', activity_regularizer=regularizers.l1(0.01) )) # experiment with different activation functions
network.add(layers.Dense(714, activation='relu')) # experiment with different activation functions

network.add(layers.Dropout(0.5))

network.add(layers.Dense(2, activation='softmax'))

# %%
network.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy', 'categorical_accuracy'])

# %%
network.fit(train_passengers, train_labels, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 891/891 [==============================] - 1s 1ms/step - loss: 0.5906 - acc: 0.7722 - categorical_accuracy: 0.7138
# Epoch 2/100
# 891/891 [==============================] - 1s 855us/step - loss: 0.4649 - acc: 0.8148 - categorical_accuracy: 0.6667
# Epoch 3/100
# 891/891 [==============================] - 1s 873us/step - loss: 0.4482 - acc: 0.8148 - categorical_accuracy: 0.6914
# Epoch 4/100
# 891/891 [==============================] - 1s 883us/step - loss: 0.4437 - acc: 0.8328 - categorical_accuracy: 0.6689
# Epoch 5/100
# 891/891 [==============================] - 1s 961us/step - loss: 0.4393 - acc: 0.8305 - categorical_accuracy: 0.6644
# Epoch 6/100
# 891/891 [==============================] - 1s 823us/step - loss: 0.4434 - acc: 0.8260 - categorical_accuracy: 0.6801
# Epoch 7/100
# 891/891 [==============================] - 1s 939us/step - loss: 0.4292 - acc: 0.8395 - categorical_accuracy: 0.6779
# Epoch 8/100
# 891/891 [==============================] - 1s 899us/step - loss: 0.4214 - acc: 0.8451 - categorical_accuracy: 0.6678
# Epoch 9/100
# 891/891 [==============================] - 1s 819us/step - loss: 0.4247 - acc: 0.8350 - categorical_accuracy: 0.6622
# Epoch 10/100
# 891/891 [==============================] - 1s 829us/step - loss: 0.4211 - acc: 0.8316 - categorical_accuracy: 0.6655
# Epoch 11/100
# 891/891 [==============================] - 1s 730us/step - loss: 0.4202 - acc: 0.8373 - categorical_accuracy: 0.6599
# 891/891 [==============================] - 1s 770us/step - loss: 0.3739 - acc: 0.8687 - categorical_accuracy: 0.6914
# Epoch 85/100
# 891/891 [==============================] - 1s 877us/step - loss: 0.3608 - acc: 0.8822 - categorical_accuracy: 0.6869
# Epoch 86/100
# 891/891 [==============================] - 1s 772us/step - loss: 0.3714 - acc: 0.8765 - categorical_accuracy: 0.7059
# Epoch 87/100
# 891/891 [==============================] - 1s 758us/step - loss: 0.3767 - acc: 0.8754 - categorical_accuracy: 0.6846
# Epoch 88/100
# 891/891 [==============================] - 1s 760us/step - loss: 0.3783 - acc: 0.8642 - categorical_accuracy: 0.6958
# Epoch 89/100
# 891/891 [==============================] - 1s 764us/step - loss: 0.3964 - acc: 0.8653 - categorical_accuracy: 0.7015
# Epoch 90/100
# 891/891 [==============================] - 1s 780us/step - loss: 0.4014 - acc: 0.8608 - categorical_accuracy: 0.7149
# Epoch 91/100
# 891/891 [==============================] - 1s 757us/step - loss: 0.4202 - acc: 0.8721 - categorical_accuracy: 0.6925
# Epoch 92/100
# 891/891 [==============================] - 1s 790us/step - loss: 0.3558 - acc: 0.8721 - categorical_accuracy: 0.6947
# Epoch 93/100
# 891/891 [==============================] - 1s 741us/step - loss: 0.4170 - acc: 0.8698 - categorical_accuracy: 0.6857
# Epoch 94/100
# 891/891 [==============================] - 1s 812us/step - loss: 0.3597 - acc: 0.8765 - categorical_accuracy: 0.6947
# Epoch 95/100
# 891/891 [==============================] - 1s 803us/step - loss: 0.3783 - acc: 0.8709 - categorical_accuracy: 0.6981
# Epoch 96/100
# 891/891 [==============================] - 1s 772us/step - loss: 0.3543 - acc: 0.8788 - categorical_accuracy: 0.7015
# Epoch 97/100
# 891/891 [==============================] - 1s 750us/step - loss: 0.3665 - acc: 0.8788 - categorical_accuracy: 0.6992
# Epoch 98/100
# 891/891 [==============================] - 1s 745us/step - loss: 0.3610 - acc: 0.8754 - categorical_accuracy: 0.6981
# Epoch 99/100
# 891/891 [==============================] - 1s 792us/step - loss: 0.3591 - acc: 0.8687 - categorical_accuracy: 0.6958
# Epoch 100/100
# 891/891 [==============================] - 1s 762us/step - loss: 0.3862 - acc: 0.8653 - categorical_accuracy: 0.7082

# %%
results = network.predict(test_passengers)

# %%
results.shape
# Out:
# (418, 2)

# %%
survived = []
for result in results:
    survived.append(result[1])
  

plt.scatter(survived, range(len(survived)))
plt.show()

# %%
# we need binary survival prediction, not a probability
binary_results = network.predict_classes(test_passengers)

# %%
df_test = pd.read_csv("test.csv") # get unwrangled version of test set with the passenger IDs

# %%
df_test['Survived'] = binary_results

# %%
df_test.drop(columns=['Pclass', 'Embarked', 'Name', 'Ticket', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Fare', 'Embarked'], inplace=True)

# %%
df_test.to_csv("predictions.csv", columns = ['PassengerId', 'Survived'])

# %%
df_test.reset_index(drop=True, inplace=True)

# %%
df_test
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         0
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         1
# 24           916         0
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         0
# 391         1283         1
# 392         1284         1
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         1
# 405         1297         1
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         0
# 411         1303         1
# 412         1304         1
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %% [markdown]
# ### TODO
# get validation set
# get sucess of model on train and validation set with plot, to make sure not overfitting
#
# make a load of synthetic features, like 'is female and lower class'
#
# rescale data
#
# use hyperparam grid search
#
# regularise model
#
# logisitc regression? SVM
#
# cross_validate
